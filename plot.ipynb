# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame.from_csv('log/ga/log.csv')
# Out:
# /Users/abeken/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   """Entry point for launching an IPython kernel.

# %%
plt.plot(df['evals'], df['fval'])
plt.xlabel('number of evaluations')
plt.ylabel('evaluation value')
plt.grid()
plt.savefig('log/ga/log.png')
